# %% [markdown]
# ## Importing Libraries

# %%
# import all necessary libraries
import nltk
nltk.download('inaugural')
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import inaugural
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from collections import Counter
import matplotlib.pyplot as plt
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package inaugural to
# [nltk_data]     C:\Users\bj\AppData\Roaming\nltk_data...
# [nltk_data]   Package inaugural is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\bj\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\bj\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ## Utilities

# %%
# Define function for count characters, words and sentences from speech
def count_character_words_sentences(speech):
  text = inaugural.raw(speech)
  characters = len(text)
  words = inaugural.words(speech)
  words_count = len(words)
  sentences = inaugural.sents(speech)
  sent_count = len(sentences)
  print(f'{speech} contains:: Characters: {characters} :: Words: {words_count} :: sentences: {sent_count} ')

# %%
# Define function for remove stopwords from speech
def remove_stop_words(speech, stop_words):
  words = inaugural.words(speech)
  cleaned_words = [w for w in words if not w.lower() in stop_words]
  return cleaned_words

# %%
# Define function for plot word cloud
def show_word_clound(words_count):
  wordcloud = WordCloud(width = 1000, height = 500).generate_from_frequencies(words_count)
  plt.figure(figsize=(10,6))
  plt.imshow(wordcloud)
  plt.axis("off")
  plt.show()
  plt.close()

# %% [markdown]
# ## 2.1 Find the number of characters, words, and sentences for the mentioned documents.

# %%
count_character_words_sentences('1941-Roosevelt.txt')
count_character_words_sentences('1961-Kennedy.txt')
count_character_words_sentences('1973-Nixon.txt')
# Out:
# 1941-Roosevelt.txt contains:: Characters: 7571 :: Words: 1536 :: sentences: 68
# 1961-Kennedy.txt contains:: Characters: 7618 :: Words: 1546 :: sentences: 52
# 1973-Nixon.txt contains:: Characters: 9991 :: Words: 2028 :: sentences: 69

# %% [markdown]
# ## 2.2 Remove all the stopwords from all three speeches.

# %%
stop_words = set(stopwords.words('english'))

# %%
cleaned_1943 = remove_stop_words('1941-Roosevelt.txt', stop_words)
cleaned_1961 = remove_stop_words('1961-Kennedy.txt', stop_words)
cleaned_1973 = remove_stop_words('1973-Nixon.txt', stop_words)
print(cleaned_1943)
# Out:
# ['national', 'day', 'inauguration', 'since', '1789', ',', 'people', 'renewed', 'sense', 'dedication', 'United', 'States', '.', 'Washington', "'", 'day', 'task', 'people', 'create', 'weld', 'together', 'nation', '.', 'Lincoln', "'", 'day', 'task', 'people', 'preserve', 'Nation', 'disruption', 'within', '.', 'day', 'task', 'people', 'save', 'Nation', 'institutions', 'disruption', 'without', '.', 'us', 'come', 'time', ',', 'midst', 'swift', 'happenings', ',', 'pause', 'moment', 'take', 'stock', '--', 'recall', 'place', 'history', ',', 'rediscover', 'may', '.', ',', 'risk', 'real', 'peril', 'inaction', '.', 'Lives', 'nations', 'determined', 'count', 'years', ',', 'lifetime', 'human', 'spirit', '.', 'life', 'man', 'three', '-', 'score', 'years', 'ten', ':', 'little', ',', 'little', 'less', '.', 'life', 'nation', 'fullness', 'measure', 'live', '.', 'men', 'doubt', '.', 'men', 'believe', 'democracy', ',', 'form', 'Government', 'frame', 'life', ',', 'limited', 'measured', 'kind', 'mystical',
# ...

# %%
words_count_1943 = Counter(cleaned_1943)
print(words_count_1943)
# Out:
# Counter({',': 77, '.': 67, '--': 25, 'know': 10, 'spirit': 9, 'life': 9, 'us': 8, 'democracy': 8, 'people': 7, 'Nation': 7, 'America': 7, 'years': 6, 'freedom': 6, "'": 5, 'nation': 5, 'human': 5, 'men': 5, 'body': 5, 'mind': 5, 'speaks': 5, 'day': 4, 'States': 4, '-': 4, ';': 4, 'new': 4, 'must': 4, 'something': 4, 'faith': 4, 'United': 3, 'task': 3, 'within': 3, 'history': 3, 'nations': 3, 'three': 3, 'live': 3, 'future': 3, 'free': 3, 'alone': 3, 'still': 3, 'every': 3, 'continent': 3, 'like': 3, 'person': 3, 'sacred': 3, 'came': 3, 'first': 3, 'destiny': 3, 'national': 2, '1789': 2, 'sense': 2, 'Washington': 2, 'create': 2, 'together': 2, 'disruption': 2, 'come': 2, 'time': 2, 'midst': 2, 'stock': 2, 'may': 2, ':': 2, 'little': 2, 'measure': 2, 'doubt': 2, 'Government': 2, 'measured': 2, 'Americans': 2, 'true': 2, 'Republic': 2, 'acted': 2, 'security': 2, 'things': 2, 'present': 2, 'many': 2, 'built': 2, 'maintained': 2, 'Constitution': 2, 'freely': 2, 'American': 2, 'seen': 2, '
# ...

# %%
# President Franklin D. Roosevelt in 1941 Speech contains: know, spirit, life occurs the most.

# %%
words_count_1961  = Counter(cleaned_1961)
print(words_count_1961)
# Out:
# Counter({',': 85, '.': 51, '--': 25, 'us': 12, 'world': 8, 'Let': 8, 'let': 8, 'sides': 8, 'new': 7, 'pledge': 7, 'citizens': 5, 'power': 5, 'shall': 5, 'free': 5, 'ask': 5, 'President': 4, 'fellow': 4, 'freedom': 4, 'man': 4, 'first': 4, 'Americans': 4, 'war': 4, 'peace': 4, 'always': 4, 'cannot': 4, 'hope': 4, 'help': 4, 'nations': 4, ':': 4, 'arms': 4, 'country': 4, 'call': 4, 'today': 3, 'well': 3, 'God': 3, 'human': 3, 'poverty': 3, 'life': 3, 'globe': 3, 'dare': 3, 'go': 3, 'generation': 3, 'know': 3, 'bear': 3, 'control': 3, 'may': 3, 'good': 3, 'join': 3, 'begin': 3, 'never': 3, 'final': 3, '"': 3, 'Vice': 2, 'Mr': 2, 'forebears': 2, 'century': 2, 'hands': 2, 'forms': 2, 'yet': 2, 'around': 2, 'rights': 2, 'hand': 2, 'revolution': 2, 'word': 2, 'forth': 2, 'time': 2, 'friend': 2, 'foe': 2, 'passed': 2, 'committed': 2, 'every': 2, 'whether': 2, 'burden': 2, 'meet': 2, 'support': 2, 'oppose': 2, 'assure': 2, 'success': 2, 'loyalty': 2, 'United': 2, 'little': 2, 'powerful': 2, '
# ...

# %%
# President John F. Kennedy in 1961 speech contains: us, world, let occurs the most

# %%
words_count_1973 = Counter(cleaned_1973)
print(words_count_1973)
# Out:
# Counter({',': 96, '.': 68, 'us': 26, 'America': 21, 'peace': 19, 'world': 17, '--': 17, 'new': 15, "'": 14, 'Let': 13, 'responsibility': 11, 'great': 9, 'home': 9, 'nation': 9, 'let': 9, 'years': 7, 'shall': 7, 'policies': 7, 'role': 7, 'make': 7, 'every': 7, 'government': 7, 'history': 7, 'better': 7, 'together': 6, 'time': 6, 'right': 6, 'people': 6, 'help': 6, ':': 5, 'four': 5, 'abroad': 5, 'era': 5, 'responsibilities': 5, 'progress': 5, 'come': 5, 'respect': 5, 'others': 5, 'act': 5, 'one': 5, 'today': 4, 'promise': 4, 'long': 4, 'work': 4, 'freedom': 4, 'God': 4, 'old': 4, 'proud': 4, 'faith': 4, 'Mr': 3, 'country': 3, 'share': 3, '?': 3, 'resolve': 3, 'retreat': 3, 'greatly': 3, 'century': 3, '-': 3, 'nations': 3, 'bold': 3, 'end': 3, 'another': 3, 'future': 3, 'forward': 3, 'build': 3, 'structure': 3, 'live': 3, 'system': 3, 'gladly': 3, 'challenges': 3, 'away': 3, 'Abroad': 3, 'way': 3, 'individual': 3, 'Government': 3, 'ask': 3, 'ashamed': 3, 'think': 3, 'spirit': 2, 'war':
# ...

# %%
# President Richard Nixon in 1973 speech contains: us, America, peace occurs the most.

# %% [markdown]
# ### 2.4 Plot the word cloud of each of the speeches of the variable. (after removing the stopwords)

# %%
show_word_clound(words_count_1943)
show_word_clound(words_count_1961)
show_word_clound(words_count_1973)
