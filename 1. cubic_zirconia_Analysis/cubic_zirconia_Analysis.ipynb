# %% [markdown]
# # Project Name: Cubic Zirconia Price Analysis using Linear Regression
# ### Mailn task: Data Analysis
# - Analysis how different variables like carat, cut, clarity depth, x, y,z are affect to price of zirconia cube.
# - Create good ML model for price prediction.

# %% [markdown]
# # Que1.1

# %%
# import pandas
import pandas as pd

# %%
# Read data from csv file and convert it into DataFrame
# For reading the data from csv file i use read_csv method of pandas
df = pd.read_csv('cubic_zirconia.csv')
df
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price
# 0       0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66    499
# 1       0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70    984
# 2       0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78   6289
# 3       0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96   1082
# 4       0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65    779
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 26962   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52  4.09   5408
# 26963   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42  2.74   1114
# 26964   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15  3.17   1656
# 26965   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20  2.60    682
# 26966   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88  4.27   5166
#
# [26967 rows x 10 columns]

# %% [markdown]
# ### Check the null values
# - If there is any null values are present in dataset then it's not good for modeling

# %%
# Check null values and datatype of all columns using info() method
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26967 entries, 0 to 26966
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    26967 non-null  float64
#  1   cut      26967 non-null  object
#  2   color    26967 non-null  object
#  3   clarity  26967 non-null  object
#  4   depth    26270 non-null  float64
#  5   table    26967 non-null  float64
#  6   x        26967 non-null  float64
#  7   y        26967 non-null  float64
#  8   z        26967 non-null  float64
#  9   price    26967 non-null  int64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 2.1+ MB

# %%
# Imporrt matplotlib and seaborn libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Univariate Analysis

# %%
# plot countplot of cut column
sns.countplot(df.cut)
# People are not interested to buy Fair and Good quality zirconia cube.

# %%
# plot countplot of color column
sns.countplot(df.color)
# people are more interested to buy E,F and G color quality cube and they are not interested to buy J, I and D color cube.

# %%
# plot countplot of clarity column
sns.countplot(df.clarity)
# Only few people are interested to buy L1, IF VVS1 clarity cube

# %%
# plot histogram of price column
df.price.hist()

# %%
# plot boxplot of price column
sns.boxplot(df.price)

# %%
# plot histogram of carat column
df.carat.hist()

# %%
# plot boxplot of carat column
sns.boxplot(df.carat)

# %%
# plot histogram of table column
df.table.hist()

# %%
# plot boxplot of table column
sns.boxplot(df.table)

# %%
# Let's find correlation in different columns
df.corr()
# Out:
#           carat     depth     table         x         y         z     price
# carat  1.000000  0.035364  0.181685  0.976368  0.941071  0.940640  0.922416
# depth  0.035364  1.000000 -0.298011 -0.018715 -0.024735  0.101624 -0.002569
# table  0.181685 -0.298011  1.000000  0.196206  0.182346  0.148944  0.126942
# x      0.976368 -0.018715  0.196206  1.000000  0.962715  0.956606  0.886247
# y      0.941071 -0.024735  0.182346  0.962715  1.000000  0.928923  0.856243
# z      0.940640  0.101624  0.148944  0.956606  0.928923  1.000000  0.850536
# price  0.922416 -0.002569  0.126942  0.886247  0.856243  0.850536  1.000000

# %%
# Let's describe data briefly
df.describe()
# Out:
#               carat         depth         table             x             y  \
# count  26967.000000  26270.000000  26967.000000  26967.000000  26967.000000
# mean       0.798375     61.745147     57.456080      5.729854      5.733569
# std        0.477745      1.412860      2.232068      1.128516      1.166058
# min        0.200000     50.800000     49.000000      0.000000      0.000000
# 25%        0.400000     61.000000     56.000000      4.710000      4.710000
# 50%        0.700000     61.800000     57.000000      5.690000      5.710000
# 75%        1.050000     62.500000     59.000000      6.550000      6.540000
# max        4.500000     73.600000     79.000000     10.230000     58.900000
#
#                   z         price
# count  26967.000000  26967.000000
# mean       3.538057   3939.518115
# std        0.720624   4024.864666
# min        0.000000    326.000000
# 25%        2.900000    945.000000
# 50%        3.520000   2375.000000
# 75%        4.040000   5360.000000
# ...

# %%
# Draw heatmap of correlation of each columns with eachother
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# ### Bivariate Analysis

# %%
# plot scatterplot between carat and price
sns.scatterplot(df.carat,df.price)

# %%
# plot scatterplot between depth and price
sns.scatterplot(df.depth,df.price)

# %%
# plot scatterplot between table and price
sns.scatterplot(df.table,df.price)

# %%
# plot scatterplot between x and price
sns.scatterplot(df.x,df.price)

# %%
# plot scatterplot between y and price
sns.scatterplot(df.y,df.price)

# %%
# plot scatterplot between z and price
sns.scatterplot(df.z,df.price)

# %% [markdown]
# # Que1.2

# %% [markdown]
# ### Fill null values

# %%
# let's fill missing value with fillna method
df.depth.fillna(df.depth.mean(),inplace=True)

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %% [markdown]
# # Que 1.3

# %% [markdown]
# ### Encode the data for modeling

# %%
# Encode the data for model training because machine can't understand categorical data
df['cut_num'] = df.cut.replace(['Fair','Good','Very Good','Premium','Ideal'],[1,2,3,4,5])
df
# Out:
#        carat        cut color clarity  depth  table     x     y     z  price  \
# 0       0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66    499
# 1       0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70    984
# 2       0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78   6289
# 3       0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96   1082
# 4       0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65    779
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...    ...
# 26962   1.11    Premium     G     SI1   62.3   58.0  6.61  6.52  4.09   5408
# 26963   0.33      Ideal     H      IF   61.9   55.0  4.44  4.42  2.74   1114
# 26964   0.51    Premium     E     VS2   61.7   58.0  5.12  5.15  3.17   1656
# 26965   0.27  Very Good     F    VVS2   61.8   56.0  4.19  4.20  2.60    682
# 26966   1.25    Premium     J     SI1   62.0   58.0  6.90  6.88  4.27   5166
#
#        cut_num
# 0            5
# ...

# %%
df[10:50]
# Out:
#     carat        cut color clarity      depth  table     x     y     z  price  \
# 10   0.32      Ideal     E     VS2  61.600000   56.0  4.40  4.43  2.72    637
# 11   1.10    Premium     D     SI1  60.700000   55.0  6.74  6.71  4.08   6468
# 12   0.50       Good     E     VS1  61.100000   58.2  5.08  5.12  3.11   1932
# 13   0.71      Ideal     D     SI2  61.600000   55.0  5.74  5.76  3.54   2767
# 14   1.50       Fair     G     VS2  66.200000   53.0  7.12  7.08  4.70  10644
# 15   0.31      Ideal     G     VS2  61.600000   55.0  4.37  4.39  2.70    544
# 16   0.34      Ideal     G     SI1  61.200000   57.0  4.56  4.53  2.78    650
# 17   1.01      Ideal     D     VS2  59.800000   56.0  6.52  6.49  3.89   7127
# 18   0.90       Good     D     SI1  61.900000   64.0  6.00  6.09  3.74   3567
# 19   0.54    Premium     G     VS2  60.000000   59.0  5.42  5.22  3.19   1637
# 20   1.04    Premium     D    VVS2  61.100000   60.0  6.54  6.51  3.99  10984
# ...

# %%
# import necessary library for encoding data
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
# Encode the data with LabelEncoder
df['color_num'] = le.fit_transform(df.color)

# %%
df[10:50]
# Out:
#     carat        cut color clarity      depth  table     x     y     z  price  \
# 10   0.32      Ideal     E     VS2  61.600000   56.0  4.40  4.43  2.72    637
# 11   1.10    Premium     D     SI1  60.700000   55.0  6.74  6.71  4.08   6468
# 12   0.50       Good     E     VS1  61.100000   58.2  5.08  5.12  3.11   1932
# 13   0.71      Ideal     D     SI2  61.600000   55.0  5.74  5.76  3.54   2767
# 14   1.50       Fair     G     VS2  66.200000   53.0  7.12  7.08  4.70  10644
# 15   0.31      Ideal     G     VS2  61.600000   55.0  4.37  4.39  2.70    544
# 16   0.34      Ideal     G     SI1  61.200000   57.0  4.56  4.53  2.78    650
# 17   1.01      Ideal     D     VS2  59.800000   56.0  6.52  6.49  3.89   7127
# 18   0.90       Good     D     SI1  61.900000   64.0  6.00  6.09  3.74   3567
# 19   0.54    Premium     G     VS2  60.000000   59.0  5.42  5.22  3.19   1637
# 20   1.04    Premium     D    VVS2  61.100000   60.0  6.54  6.51  3.99  10984
# ...

# %%
# Encode the data for model training because machine can't understand categorical data
df['clarity_num'] = df.clarity.replace(['I1','SI2','SI1','VS2','VS1','VVS2','VVS1','IF'],[0,1,2,3,4,5,6,7])

# %%
df.head(10)
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price  \
# 0   0.30      Ideal     E     SI1   62.1   58.0  4.27  4.29  2.66    499
# 1   0.33    Premium     G      IF   60.8   58.0  4.42  4.46  2.70    984
# 2   0.90  Very Good     E    VVS2   62.2   60.0  6.04  6.12  3.78   6289
# 3   0.42      Ideal     F     VS1   61.6   56.0  4.82  4.80  2.96   1082
# 4   0.31      Ideal     F    VVS1   60.4   59.0  4.35  4.43  2.65    779
# 5   1.02      Ideal     D     VS2   61.5   56.0  6.46  6.49  3.99   9502
# 6   1.01       Good     H     SI1   63.7   60.0  6.35  6.30  4.03   4836
# 7   0.50    Premium     E     SI1   61.5   62.0  5.09  5.06  3.12   1415
# 8   1.21       Good     H     SI1   63.8   64.0  6.72  6.63  4.26   5407
# 9   0.35      Ideal     F     VS2   60.5   57.0  4.52  4.60  2.76    706
#
#    cut_num  color_num  clarity_num
# 0        5          1            2
# 1        4          3            7
# 2        3          1            5
# ...

# %%
# Devide DataFrame into x and y part
x_final = df.drop(['cut','color','clarity','price'],axis=1)
x_final
# Out:
#        carat  depth  table     x     y     z  cut_num  color_num  clarity_num
# 0       0.30   62.1   58.0  4.27  4.29  2.66        5          1            2
# 1       0.33   60.8   58.0  4.42  4.46  2.70        4          3            7
# 2       0.90   62.2   60.0  6.04  6.12  3.78        3          1            5
# 3       0.42   61.6   56.0  4.82  4.80  2.96        5          2            4
# 4       0.31   60.4   59.0  4.35  4.43  2.65        5          2            6
# ...      ...    ...    ...   ...   ...   ...      ...        ...          ...
# 26962   1.11   62.3   58.0  6.61  6.52  4.09        4          3            2
# 26963   0.33   61.9   55.0  4.44  4.42  2.74        5          4            7
# 26964   0.51   61.7   58.0  5.12  5.15  3.17        4          1            3
# 26965   0.27   61.8   56.0  4.19  4.20  2.60        3          2            5
# 26966   1.25   62.0   58.0  6.90  6.88  4.27        4          6            2
#
# [26967 rows x 9 columns]

# %%
y_final = df.price
y_final
# Out:
# 0         499
# 1         984
# 2        6289
# 3        1082
# 4         779
#          ...
# 26962    5408
# 26963    1114
# 26964    1656
# 26965     682
# 26966    5166
# Name: price, Length: 26967, dtype: int64

# %% [markdown]
# ### Data Split

# %%
# split dataset into training and testing part
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_final,y_final,test_size=0.3)

# %%
x_train
# Out:
#        carat      depth  table     x     y     z  cut_num  color_num  \
# 14493   1.70  62.600000   54.1  7.58  7.63  4.77        5          4
# 8577    1.20  61.300000   60.0  6.77  6.84  4.17        3          1
# 26879   0.51  61.745147   58.0  5.10  5.13  3.12        3          1
# 14560   0.33  61.800000   56.0  4.45  4.48  2.76        5          0
# 7839    1.01  61.745147   62.0  6.45  6.37  3.97        4          4
# ...      ...        ...    ...   ...   ...   ...      ...        ...
# 25323   2.01  62.200000   56.0  8.05  8.08  5.02        5          2
# 24157   1.10  61.300000   54.0  6.69  6.65  4.09        5          3
# 11533   0.26  61.200000   56.0  4.11  4.16  2.53        5          4
# 16439   0.35  61.600000   54.0  4.55  4.58  2.81        5          3
# 15757   2.30  62.600000   54.0  8.42  8.46  5.28        5          4
#
#        clarity_num
# 14493            0
# 8577             6
# 26879            2
# 14560            3
# 7839             3
# ...

# %%
x_test
# Out:
#        carat      depth  table     x     y     z  cut_num  color_num  \
# 2641    0.63  61.400000   54.0  5.54  5.56  3.41        5          6
# 24122   1.16  62.300000   57.0  6.72  6.66  4.17        5          3
# 8224    1.15  61.700000   56.0  6.72  6.76  4.16        5          3
# 24229   0.46  61.745147   57.0  4.91  4.95  3.10        3          5
# 19414   1.08  61.000000   59.0  6.66  6.61  4.05        4          0
# ...      ...        ...    ...   ...   ...   ...      ...        ...
# 8890    1.03  61.000000   58.0  6.52  6.47  3.96        4          5
# 11956   0.39  59.700000   58.0  4.73  4.75  2.83        4          2
# 5018    1.20  58.600000   57.0  7.01  6.96  4.09        5          4
# 4852    0.77  63.400000   57.0  5.80  5.84  3.69        2          1
# 6573    1.30  62.300000   54.0  6.97  7.03  4.36        5          1
#
#        clarity_num
# 2641             1
# 24122            3
# 8224             2
# 24229            6
# 19414            4
# ...

# %%
y_train
# Out:
# 14493     7068
# 8577     13015
# 26879     1343
# 14560      781
# 7839      4559
#          ...
# 25323    17078
# 24157     6535
# 11533      468
# 16439      563
# 15757    18108
# Name: price, Length: 18876, dtype: int64

# %%
y_test
# Out:
# 2641      1065
# 24122     7203
# 8224      5224
# 24229     1163
# 19414     8999
#          ...
# 8890      4038
# 11956     1232
# 5018      3763
# 4852      3291
# 6573     15874
# Name: price, Length: 8091, dtype: int64

# %% [markdown]
# ### Apply LinearRegression

# %%
# import LinearRegression from sklearn and create object of it
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
# train model using Linear Regression
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Perfomane Check

# %%
# check model accuracy using score method
lr.score(x_test,y_test)
# Out:
# 0.862799258606664

# %%
y_predicted = lr.predict(x_test)

# %%
# import r2_score from sklearn for calculating R*R
from sklearn.metrics import r2_score

# %%
# calculate R*R using r2_score
r2_score(y_test,y_predicted)
# Out:
# 0.862799258606664

# %%
# import mean_squared_error from sklearn
from sklearn.metrics import mean_squared_error

# %%
# calculate mean squared error
mean_squared_error(y_test,y_predicted)
# Out:
# 2281088.651587293

# %% [markdown]
# ### Inference: Basis on these predictions, what are the business insights and recommendations
# - In cut category Ideal and Premium cubes are contain more than 50% of total cell that means people are more prefer to buy Ideal or Premium category cube so companey should more focus on this two category for advertisement or production
# - There is very low chance for Fair and good category to sold because people don’t prefer to buy this two category cube
# - In color column if cube are in E, F or G color than there is high chance for selling and which cube contain J or I color they are low chance of selling. So companey should focus on E, F or G color cube Production rather than producing I and J color Production.
# - If cube’s clarity is SL1, VS2 or SL2 then there is high chance for selling and cube’s clarity is L1, IF or VVS1 then there is very low chance for selling so companey should focus on building or pramoting cubes which are contain SL1, VS2 or SL2 clarity.
# - We can see clearly from price histogram, if cube price is increase than chance of selling that perticular cube is decrise. So companey should focus on building low price cube
# - We can see clearly from carat histogram, if carat is more than 1 means low chance of cube selling
# - It is clearly shown in table histogram around 90% cube have table value in range 55-61 so companey should focus on it
